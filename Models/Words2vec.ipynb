# %% [markdown]
# ## **THE WORD2VEC MODEL**

# %%
import pandas as pd
import numpy as np
import os
from gensim.models import Word2Vec
import logging

# Configure logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

def load_and_preprocess_data(file_path):
    """
  
    
    Args:
        file_path (str): Path to the Excel file
    
    Returns:
        tuple: (transactions as list of lists, unique products list, original dataframe)
    """
    # Read Excel file
    df = pd.read_excel(file_path)
    
    # Clean data
    df.dropna(subset=['Itemname'], inplace=True)
    
    # Group transactions
    transactions = df.groupby('BillNo')['Itemname'].apply(list).values.tolist()
    
    # Get unique products
    unique_products = df['Itemname'].unique().tolist()
    
    return transactions, unique_products, df

def train_word2vec_model(transactions, vector_size=100, window=5, min_count=2):
    """
    Train Word2Vec model on transaction data.
    
    Args:
        transactions (list of lists): Transaction data
        vector_size (int): Dimensionality of the word vectors
        window (int): Context window size
        min_count (int): Minimum frequency for a word to be included
    
    Returns:
        Word2Vec model
    """
    # Train Word2Vec model using Skip-Gram with Negative Sampling
    model = Word2Vec(
        sentences=transactions, 
        vector_size=vector_size,  # Embedding dimensionality
        window=window,  # Context window size
        sg=1,  # Skip-gram model (1) vs CBOW (0)
        negative=5,  # Negative sampling
        min_count=min_count,  # Ignore words with frequency below this
        workers=4,  # Parallel training
        epochs=10  # Number of training epochs
    )
    
    return model

def generate_comprehensive_complementary_products(model, unique_products, topn=10):
    """
    Generate a comprehensive dataset of complementary products for each unique item.
    
    Args:
        model (Word2Vec): Trained Word2Vec model
        unique_products (list): List of unique products
        topn (int): Number of top similar products to find
    
    Returns:
        pandas.DataFrame: Comprehensive dataset of complementary products
    """
    # Prepare lists to store results
    comprehensive_results = []
    
    # Find complementary products for each unique product
    for product in unique_products:
        try:
            # Find most similar products
            similar_products = model.wv.most_similar(product, topn=topn)
            
            # Prepare the list of complementary products for this item
            complementary_list = [
                {
                    'Original Product': product,
                    'Complementary Product': comp_product,
                    'Similarity Score': similarity,
                    'Rank': rank + 1
                }
                for rank, (comp_product, similarity) in enumerate(similar_products)
            ]
            
            comprehensive_results.extend(complementary_list)
        
        except KeyError:
            # Skip products not in the model's vocabulary
            print(f"Product '{product}' not found in the model vocabulary.")
    
    # Convert results to DataFrame
    complementary_products_df = pd.DataFrame(comprehensive_results)
    
    return complementary_products_df

def analyze_complementary_products(complementary_products_df):
    """
    Analyze the generated complementary products dataset.
    
    Args:
        complementary_products_df (pandas.DataFrame): Complementary products dataset
    
    Returns:
        dict: Analysis insights
    """
    analysis = {
        'Total Unique Original Products': complementary_products_df['Original Product'].nunique(),
        'Total Complementary Product Pairs': len(complementary_products_df),
        'Average Similarity Score': complementary_products_df['Similarity Score'].mean(),
        'Median Similarity Score': complementary_products_df['Similarity Score'].median(),
        'Top 10 Strongest Complementary Relationships': (
            complementary_products_df.nlargest(10, 'Similarity Score')
            [['Original Product', 'Complementary Product', 'Similarity Score']]
        )
    }
    
    return analysis

def main():
    # Set file path - MODIFY THIS TO YOUR ACTUAL FILE PATH
    path = r'C:\Users\moham\Apriori_VS_Word2Vec\Dataset'
    excel_file = 'df_merged_items_category.xlsx' 
    excel_file_path = os.path.join(path, excel_file)
    
    # Load and preprocess transaction data
    print("Loading and preprocessing transaction data...")
    transactions, unique_products, original_df = load_and_preprocess_data(excel_file_path)
    
    # Train Word2Vec model
    print("Training Word2Vec model...")
    word2vec_model = train_word2vec_model(transactions)
    
    # Generate comprehensive complementary products dataset
    print("Generating comprehensive complementary products dataset...")
    comprehensive_complementary_products_df = generate_comprehensive_complementary_products(
        word2vec_model, 
        unique_products, 
        topn=10  # Number of top complementary products per item
    )
    
    # Analyze complementary products
    print("Analyzing complementary products...")
    analysis_results = analyze_complementary_products(comprehensive_complementary_products_df)
    
    # Save results
    output_path = os.path.join(path, 'comprehensive_complementary_products.xlsx')
    comprehensive_complementary_products_df.to_excel(output_path, index=False)
    
    # Print analysis results
    print("\nComplementary Products Analysis:")
    for key, value in analysis_results.items():
        print(f"\n{key}:")
        print(value)
    
    # Save model
    model_path = os.path.join(path, 'comprehensive_product2vec_model.bin')
    word2vec_model.save(model_path)
    
    print(f"\nResults saved to {output_path}")
    print(f"Model saved to {model_path}")

if __name__ == "__main__":
    main()
# Out:
# Loading and preprocessing transaction data...
# 2025-04-06 15:30:28,299 : INFO : collecting all words and their counts
# 2025-04-06 15:30:28,300 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2025-04-06 15:30:28,348 : INFO : PROGRESS: at sentence #10000, processed 244376 words, keeping 3614 word types
# 2025-04-06 15:30:28,386 : INFO : PROGRESS: at sentence #20000, processed 513626 words, keeping 4179 word types
# 2025-04-06 15:30:28,388 : INFO : collected 4185 word types from a corpus of 520609 raw words and 20208 sentences
# 2025-04-06 15:30:28,389 : INFO : Creating a fresh vocabulary
# 2025-04-06 15:30:28,409 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=2 retains 3877 unique words (92.64% of original 4185, drops 308)', 'datetime': '2025-04-06T15:30:28.409092', 'gensim': '4.3.3', 'python': '3.10.16 | packaged by Anaconda, Inc. | (main, Dec 11 2024, 16:19:12) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'prepare_vocab'}
# 2025-04-06 15:30:28,410 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=2 leaves 520301 word corpus (99.94% of original 520609, drops 308)', 'datetime': '2025-04-06T15:30:28.410421', 'gensim': '4.3.3', 'python': '3.10.16 | packaged by Anaconda, Inc. | (main, Dec 11 2024, 16:19:12) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'prepare_vocab'}
# 2025-04-06 15:30:28,497 : INFO : deleting the raw counts dictionary of 4185 items
# Training Word2Vec model...
# 2025-04-06 15:30:28,498 : INFO : sample=0.001 downsamples 6 most-common words
# 2025-04-06 15:30:28,500 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 518266.4566297258 word corpus (99.6%% of prior 520301)', 'datetime': '2025-04-06T15:30:28.500949', 'gensim': '4.3.3', 'python': '3.10.16 | packaged by Anaconda, Inc. | (main, Dec 11 2024, 16:19:12) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'prepare_vocab'}
# 2025-04-06 15:30:28,615 : INFO : estimated required memory for 3877 words and 100 dimensions: 5040100 bytes
# 2025-04-06 15:30:28,616 : INFO : resetting layer weights
# 2025-04-06 15:30:28,623 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-04-06T15:30:28.623789', 'gensim': '4.3.3', 'python': '3.10.16 | packaged by Anaconda, Inc. | (main, Dec 11 2024, 16:19:12) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'build_vocab'}
# 2025-04-06 15:30:28,624 : INFO : Word2Vec lifecycle event {'msg': 'training model with 4 workers on 3877 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2025-04-06T15:30:28.624795', 'gensim': '4.3.3', 'python': '3.10.16 | packaged by Anaconda, Inc. | (main, Dec 11 2024, 16:19:12) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'train'}
# 2025-04-06 15:30:29,657 : INFO : EPOCH 0 - PROGRESS: at 66.04% examples, 320345 words/s, in_qsize 8, out_qsize 0
# 2025-04-06 15:30:30,116 : INFO : EPOCH 0: training on 520609 raw words (518211 effective words) took 1.5s, 350677 effective words/s
# 2025-04-06 15:30:31,188 : INFO : EPOCH 1 - PROGRESS: at 69.47% examples, 326061 words/s, in_qsize 7, out_qsize 0
# 2025-04-06 15:30:31,639 : INFO : EPOCH 1: training on 520609 raw words (518265 effective words) took 1.5s, 342484 effective words/s
# 2025-04-06 15:30:32,651 : INFO : EPOCH 2 - PROGRESS: at 66.04% examples, 326321 words/s, in_qsize 8, out_qsize 0
# 2025-04-06 15:30:33,129 : INFO : EPOCH 2: training on 520609 raw words (518225 effective words) took 1.5s, 350433 effective words/s
# 2025-04-06 15:30:34,221 : INFO : EPOCH 3 - PROGRESS: at 69.75% examples, 320279 words/s, in_qsize 8, out_qsize 0
# 2025-04-06 15:30:34,646 : INFO : EPOCH 3: training on 520609 raw words (518296 effective words) took 1.5s, 344019 effective words/s
# 2025-04-06 15:30:35,690 : INFO : EPOCH 4 - PROGRESS: at 73.35% examples, 354443 words/s, in_qsize 8, out_qsize 0
# 2025-04-06 15:30:36,056 : INFO : EPOCH 4: training on 520609 raw words (518292 effective words) took 1.4s, 370304 effective words/s
# 2025-04-06 15:30:37,145 : INFO : EPOCH 5 - PROGRESS: at 68.02% examples, 312446 words/s, in_qsize 7, out_qsize 0
# 2025-04-06 15:30:37,649 : INFO : EPOCH 5: training on 520609 raw words (518325 effective words) took 1.6s, 327698 effective words/s
# 2025-04-06 15:30:38,663 : INFO : EPOCH 6 - PROGRESS: at 62.39% examples, 306100 words/s, in_qsize 7, out_qsize 0
# 2025-04-06 15:30:39,187 : INFO : EPOCH 6: training on 520609 raw words (518240 effective words) took 1.5s, 339478 effective words/s
# 2025-04-06 15:30:40,205 : INFO : EPOCH 7 - PROGRESS: at 62.39% examples, 305209 words/s, in_qsize 7, out_qsize 0
# 2025-04-06 15:30:40,733 : INFO : EPOCH 7: training on 520609 raw words (518243 effective words) took 1.5s, 338059 effective words/s
# 2025-04-06 15:30:41,751 : INFO : EPOCH 8 - PROGRESS: at 69.75% examples, 345111 words/s, in_qsize 7, out_qsize 0
# 2025-04-06 15:30:42,180 : INFO : EPOCH 8: training on 520609 raw words (518288 effective words) took 1.4s, 361741 effective words/s
# 2025-04-06 15:30:43,273 : INFO : EPOCH 9 - PROGRESS: at 73.35% examples, 340165 words/s, in_qsize 8, out_qsize 0
# 2025-04-06 15:30:43,646 : INFO : EPOCH 9: training on 520609 raw words (518273 effective words) took 1.4s, 357546 effective words/s
# 2025-04-06 15:30:43,648 : INFO : Word2Vec lifecycle event {'msg': 'training on 5206090 raw words (5182658 effective words) took 15.0s, 344988 effective words/s', 'datetime': '2025-04-06T15:30:43.648345', 'gensim': '4.3.3', 'python': '3.10.16 | packaged by Anaconda, Inc. | (main, Dec 11 2024, 16:19:12) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'train'}
# 2025-04-06 15:30:43,649 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=3877, vector_size=100, alpha=0.025>', 'datetime': '2025-04-06T15:30:43.649431', 'gensim': '4.3.3', 'python': '3.10.16 | packaged by Anaconda, Inc. | (main, Dec 11 2024, 16:19:12) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'created'}
# Generating comprehensive complementary products dataset...
# Product 'GIRLY PINK TOOL SET' not found in the model vocabulary.
# Product 'PINK MARSHMALLOW SCARF KNITTING KIT' not found in the model vocabulary.
# Product 'CAKESTAND, 3 TIER, LOVEHEART' not found in the model vocabulary.
# Product 'GLASS BELL JAR SMALL' not found in the model vocabulary.
# Product 'GLASS BELL JAR LARGE' not found in the model vocabulary.
# Product 'VINTAGE BLUE TINSEL REEL' not found in the model vocabulary.
# Product 'JARDIN ETCHED GLASS BUTTER DISH' not found in the model vocabulary.
# Product 'WEEKEND BAG VINTAGE ROSE PAISLEY' not found in the model vocabulary.
# Product 'WRAP  PINK FLOCK' not found in the model vocabulary.
# Product 'OCEAN SCENT CANDLE JEWELLED DRAWER' not found in the model vocabulary.
# Product 'PINK BAROQUE FLOCK CANDLE HOLDER' not found in the model vocabulary.
# Product 'BEADED LOVE HEART JEWELLERY SET' not found in the model vocabulary.
# Product 'PINK PAINTED KASHMIRI CHAIR' not found in the model vocabulary.
# Product 'TEA TIME BREAKFAST BASKET' not found in the model vocabulary.
# Product 'RED ROSE AND LACE C/COVER' not found in the model vocabulary.
# Product 'FUNKY MONKEY MUG' not found in the model vocabulary.
# Product 'BREAD BIN, DINER STYLE, MINT' not found in the model vocabulary.
# Product 'BREAD BIN, DINER STYLE, IVORY' not found in the model vocabulary.
# Product '4 GOLD FLOCK CHRISTMAS BALLS' not found in the model vocabulary.
# Product '72 CAKE CASES VINTAGE CHRISTMAS' not found in the model vocabulary.
# Product 'WRAP BLUE RUSSIAN FOLKART' not found in the model vocabulary.
# Product 'DUSTY PINK CHRISTMAS TREE 30CM' not found in the model vocabulary.
# Product 'BLACKCHRISTMAS TREE 30CM' not found in the model vocabulary.
# Product 'SET/4 2 TONE EGG SHAPE MIXING BOWLS' not found in the model vocabulary.
# Product 'GARDENERS KNEELING PAD' not found in the model vocabulary.
# Product 'COUNTRY COTTAGE  DOORSTOP GREEN' not found in the model vocabulary.
# Product 'WATERING CAN SINGLE HOOK PISTACHIO' not found in the model vocabulary.
# Product 'SET/6 IVORY BIRD T-LIGHT CANDLES' not found in the model vocabulary.
# Product 'BLUE NEW BAROQUE FLOCK CANDLESTICK' not found in the model vocabulary.
# Product 'CHRISTMAS CRAFT HEART STOCKING' not found in the model vocabulary.
# Product '*Boombox Ipod Classic' not found in the model vocabulary.
# Product 'faulty' not found in the model vocabulary.
# Product 'SET OF 3 PINK FLYING DUCKS' not found in the model vocabulary.
# Product 'PINK FEATHER CHRISTMAS DECORATION' not found in the model vocabulary.
# Product 'PINK BERTIE MOBILE PHONE CHARM' not found in the model vocabulary.
# Product 'BLACK CHRISTMAS FLOCK DROPLET' not found in the model vocabulary.
# Product 'PINK/WHITE GLASS DEMI CHOKER' not found in the model vocabulary.
# Product 'GOLD COSMETICS BAG WITH BUTTERFLY' not found in the model vocabulary.
# Product 'BAKING MOULD TOFFEE CUP  CHOCOLATE' not found in the model vocabulary.
# Product 'BAKING MOULD CUPCAKE CHOCOLATE' not found in the model vocabulary.
# Product 'JAM JAR WITH BLUE LID' not found in the model vocabulary.
# Product 'amazon sales' not found in the model vocabulary.
# Product 'OPULENT VELVET SET/3 CANDLES' not found in the model vocabulary.
# Product 'KEEP OUT GIRLS DOOR HANGER' not found in the model vocabulary.
# Product 'WHITE DOVE HONEYCOMB PAPER GARLAND' not found in the model vocabulary.
# Product 'ACRYLIC JEWEL SNOWFLAKE,PINK' not found in the model vocabulary.
# Product 'FIRE POLISHED GLASS NECKL GOLD' not found in the model vocabulary.
# Product 'BLUE GINGHAM ROSE CUSHION COVER' not found in the model vocabulary.
# Product 'CAKE STAND LACE WHITE' not found in the model vocabulary.
# Product 'CURIOUS IMAGES SCRAP BOOK SET' not found in the model vocabulary.
# Product 'SET OF THREE VINTAGE GIFT WRAPS' not found in the model vocabulary.
# Product 'BLOSSOM IMAGES SCRAP BOOK SET' not found in the model vocabulary.
# Product 'GREEN PENDANT SHELL NECKLACE' not found in the model vocabulary.
# Product 'PURPLE CHUNKY GLASS+BEAD NECKLACE' not found in the model vocabulary.
# Product 'ETCHED GLASS STAR TREE DECORATION' not found in the model vocabulary.
# Product 'PINK BOUDOIR T-LIGHT HOLDER' not found in the model vocabulary.
# Product 'WHITE ANEMONE ARTIFICIAL FLOWER' not found in the model vocabulary.
# Product 'HOT WATER BOTTLE BABUSHKA LARGE' not found in the model vocabulary.
# Product 'BIRTHDAY BANNER TAPE' not found in the model vocabulary.
# Product 'CAMOUFLAGE DOG COLLAR' not found in the model vocabulary.
# Product 'LARGE ROUND CUTGLASS CANDLESTICK' not found in the model vocabulary.
# Product 'RED PURSE WITH PINK HEART' not found in the model vocabulary.
# Product 'PINK DOLLY HAIR CLIPS' not found in the model vocabulary.
# Product 'mouldy, thrown away.' not found in the model vocabulary.
# Product 'PINK CHERRY LIGHTS' not found in the model vocabulary.
# Product 'BLUE CRYSTAL BOOT PHONE CHARM' not found in the model vocabulary.
# Product 'GLASS CAKE COVER AND PLATE' not found in the model vocabulary.
# Product 'PINK POLKADOT KIDS BAG' not found in the model vocabulary.
# Product 'ROSE PENDANT TRIPLE SHELL NECKLACE' not found in the model vocabulary.
# Product 'PINK CHERRY BLOSSOM CUP & SAUCER' not found in the model vocabulary.
# Product 'Given away' not found in the model vocabulary.
# Product 'Dotcom' not found in the model vocabulary.
# Product 'TINY CRYSTAL BRACELET RED' not found in the model vocabulary.
# Product 'EASTER CRAFT IVY WREATH WITH CHICK' not found in the model vocabulary.
# Product 'label mix up' not found in the model vocabulary.
# Product 'samples/damages' not found in the model vocabulary.
# Product 'OOH LA LA DOGS COLLAR' not found in the model vocabulary.
# Product 'INCENSE BAZAAR PEACH' not found in the model vocabulary.
# Product 'OCEAN STRIPE HAMMOCK' not found in the model vocabulary.
# Product 'M/COLOUR POM-POM CURTAIN' not found in the model vocabulary.
# Product 'BLACK CHERRY LIGHTS' not found in the model vocabulary.
# Product 'incorrectly made-thrown away.' not found in the model vocabulary.
# Product 'BLUE/NAT SHELL NECKLACE W PENDANT' not found in the model vocabulary.
# Product 'SCALLOP SHELL SOAP DISH' not found in the model vocabulary.
# Product 'NECKLACE+BRACELET SET PINK DAISY' not found in the model vocabulary.
# Product 'PINK CHRYSANTHEMUMS ART FLOWER' not found in the model vocabulary.
# Product 'HEAVENS SCENT FRAGRANCE OILS ASSTD' not found in the model vocabulary.
# Product 'BLUE DROP EARRINGS W BEAD CLUSTER' not found in the model vocabulary.
# Product 'PURPLE ANEMONE ARTIFICIAL FLOWER' not found in the model vocabulary.
# Product 'showroom' not found in the model vocabulary.
# Product 'PINK CRYSTAL GUITAR PHONE CHARM' not found in the model vocabulary.
# Product 'MIA' not found in the model vocabulary.
# Product 'PURPLE/TURQ FLOWERS HANDBAG' not found in the model vocabulary.
# Product 'Dotcom set' not found in the model vocabulary.
# Product 'wrongly sold as sets' not found in the model vocabulary.
# Product 'Amazon sold sets' not found in the model vocabulary.
# Product 'dotcom sold sets' not found in the model vocabulary.
# Product 'wrongly sold sets' not found in the model vocabulary.
# Product '? sold as sets?' not found in the model vocabulary.
# Product '?sold as sets?' not found in the model vocabulary.
# Product 'Thrown away.' not found in the model vocabulary.
# Product 'damages/display' not found in the model vocabulary.
# Product 'damaged stock' not found in the model vocabulary.
# Product 'broken' not found in the model vocabulary.
# Product 'throw away' not found in the model vocabulary.
# Product 'wrong barcode (22467)' not found in the model vocabulary.
# Product 'wrongly sold (22719) barcode' not found in the model vocabulary.
# Product 'HEN HOUSE W CHICK IN NEST' not found in the model vocabulary.
# Product 'WIRE FLOWER T-LIGHT HOLDER' not found in the model vocabulary.
# Product 'RUBY GLASS NECKLACE 42"' not found in the model vocabulary.
# Product 'PINK SMALL GLASS CAKE STAND' not found in the model vocabulary.
# Product 'wrong barcode' not found in the model vocabulary.
# Product 'barcode problem' not found in the model vocabulary.
# Product 'BIG POLKADOT MUG' not found in the model vocabulary.
# Product '?lost' not found in the model vocabulary.
# Product 'ASSORTED COLOUR SILK GLASSES CASE' not found in the model vocabulary.
# Product 'thrown away-can't sell.' not found in the model vocabulary.
# Product 'thrown away-can't sell' not found in the model vocabulary.
# Product 'rcvd be air temp fix for dotcom sit' not found in the model vocabulary.
# Product 'PACK 4 FLOWER/BUTTERFLY PATCHES' not found in the model vocabulary.
# Product 'MUMMY MOUSE RED GINGHAM RIBBON' not found in the model vocabulary.
# Product 're dotcom quick fix.' not found in the model vocabulary.
# Product 'SMALL TAHITI BEACH BAG' not found in the model vocabulary.
# Product 'Dotcom sold in 6's' not found in the model vocabulary.
# Product 'sold in set?' not found in the model vocabulary.
# Product 'cracked' not found in the model vocabulary.
# Product 'sold as 22467' not found in the model vocabulary.
# Product 'ORANGE FELT VASE + FLOWERS' not found in the model vocabulary.
# Product 'mystery! Only ever imported 1800' not found in the model vocabulary.
# Product 'MERCHANT CHANDLER CREDIT ERROR, STO' not found in the model vocabulary.
# Product 'POSSIBLE DAMAGES OR LOST?' not found in the model vocabulary.
# Product 'BLUE PADDED SOFT MOBILE' not found in the model vocabulary.
# Product 'DAMAGED' not found in the model vocabulary.
# Product 'did  a credit  and did not tick ret' not found in the model vocabulary.
# Product 'BLACK GLASS/SHELL/PEARL NECKLACE' not found in the model vocabulary.
# Product 'ORANGE/FUSCHIA STONES NECKLACE' not found in the model vocabulary.
# Product 'MARIE ANTOIENETT TRINKET BOX GOLD' not found in the model vocabulary.
# Product 'Display' not found in the model vocabulary.
# Product 'Missing' not found in the model vocabulary.
# Product 'BAROQUE BUTTERFLY EARRINGS RED' not found in the model vocabulary.
# Product 'wrong code?' not found in the model vocabulary.
# Product 'wrong code' not found in the model vocabulary.
# Product 'adjust' not found in the model vocabulary.
# Product 'LASER CUT MULTI STRAND NECKLACE' not found in the model vocabulary.
# Product 'HAYNES CAMPER SHOULDER BAG' not found in the model vocabulary.
# Product 'PINK FLOCK PHOTO FRAME' not found in the model vocabulary.
# Product 'damages/showroom etc' not found in the model vocabulary.
# Product 'samples' not found in the model vocabulary.
# Product 'damages/credits from ASOS.' not found in the model vocabulary.
# Product 'POLYESTER FILLER PAD 60x40cm' not found in the model vocabulary.
# Product 'FOOD COVER WITH BEADS , SET 2 SIZES' not found in the model vocabulary.
# Product 'Not rcvd in 10/11/2010 delivery' not found in the model vocabulary.
# Product 'Thrown away-rusty' not found in the model vocabulary.
# Product 'CRYSTAL CHANDELIER T-LIGHT HOLDER' not found in the model vocabulary.
# Product 'IVORY PANTRY HANGING LAMP' not found in the model vocabulary.
# Product 'ZINC PLANT POT HOLDER' not found in the model vocabulary.
# Product 'PEARL & SHELL 42"NECKL. IVORY' not found in the model vocabulary.
# Product 'sold as set/6 by dotcom' not found in the model vocabulary.
# Product 'damages/dotcom?' not found in the model vocabulary.
# Product 'on cargo order' not found in the model vocabulary.
# Product 'LILY BROOCH WHITE/SILVER COLOUR' not found in the model vocabulary.
# Product '16 PC CUTLERY SET PANTRY DESIGN' not found in the model vocabulary.
# Product 'CAPIZ CHANDELIER' not found in the model vocabulary.
# Product 'reverse previous adjustment' not found in the model vocabulary.
# Product 'ZINC STAR T-LIGHT HOLDER' not found in the model vocabulary.
# Product 'Water damaged' not found in the model vocabulary.
# Product 'BAROQUE BUTTERFLY EARRINGS MONTANA' not found in the model vocabulary.
# Product 'WHITE FRANGIPANI HAIR CLIP' not found in the model vocabulary.
# Product 'sold as set on dotcom and amazon' not found in the model vocabulary.
# Product 'water damage' not found in the model vocabulary.
# Product 'sold as set by dotcom' not found in the model vocabulary.
# Product 'DOLPHIN WINDMILL' not found in the model vocabulary.
# Product 'GLASS BEAD HOOP NECKLACE BLACK' not found in the model vocabulary.
# Product 'CHRISTMAS TABLE CANDLE SILVER SPIKE' not found in the model vocabulary.
# Product 'Printing smudges/thrown away' not found in the model vocabulary.
# Product 'to push order througha s stock was' not found in the model vocabulary.
# Product 'found some more on shelf' not found in the model vocabulary.
# Product 'Show Samples' not found in the model vocabulary.
# Product 'FOUND' not found in the model vocabulary.
# Product 'mix up with c' not found in the model vocabulary.
# Product 'mouldy, unsaleable.' not found in the model vocabulary.
# Product 'BELL HEART ANTIQUE GOLD' not found in the model vocabulary.
# Product 'DOORKNOB CRACKED GLAZE PINK' not found in the model vocabulary.
# Product 'DOORKNOB CRACKED GLAZE GREEN' not found in the model vocabulary.
# Product 'TRAVEL CARD WALLET DOTCOMGIFTSHOP' not found in the model vocabulary.
# Product 'WHITE WITH METAL BAG CHARM' not found in the model vocabulary.
# Product 'GREEN WITH METAL BAG CHARM' not found in the model vocabulary.
# Product 'LILAC FEATHERS CURTAIN' not found in the model vocabulary.
# Product 'DOORKNOB CRACKED GLAZE BLUE' not found in the model vocabulary.
# Product 'ENAMEL MUG PANTRY' not found in the model vocabulary.
# Product 'wrongly marked. 23343 in box' not found in the model vocabulary.
# Product 'came coded as 20713' not found in the model vocabulary.
# Product 'alan hodge cant mamage this section' not found in the model vocabulary.
# Product 'AMBER BERTIE MOBILE PHONE CHARM' not found in the model vocabulary.
# Product 'PINK BEADS+HAND PHONE CHARM' not found in the model vocabulary.
# Product 'BLUE/YELLOW CERAMIC CANDLE HOLDER' not found in the model vocabulary.
# Product 'GREEN/BLUE CERAMIC CANDLE HOLDER' not found in the model vocabulary.
# Product 'FBA' not found in the model vocabulary.
# Product 'BIRD ON BRANCH CANVAS SCREEN' not found in the model vocabulary.
# Product 'BLUE MONTE CARLO HANDBAG' not found in the model vocabulary.
# Product 'stock creditted wrongly' not found in the model vocabulary.
# Product 'incorrectly put back into stock' not found in the model vocabulary.
# Product 'VINTAGE BEAD PINK JEWEL STAND' not found in the model vocabulary.
# Product 'Damages/samples' not found in the model vocabulary.
# Product 'Dotcomgiftshop Gift Voucher Â£100.00' not found in the model vocabulary.
# Product 'Sold as 1 on dotcom' not found in the model vocabulary.
# Product 'BLUE PAINTED KASHMIRI CHAIR' not found in the model vocabulary.
# Product 'SET OF 4 KNICK KNACK TINS  DOILEY' not found in the model vocabulary.
# Product 'PINK ACRYLIC JEWEL SNOWFLAKE' not found in the model vocabulary.
# Product 'taig adjust no stock' not found in the model vocabulary.
# Product 'HAPPY BIRTHDAY CARD TEDDY/CAKE' not found in the model vocabulary.
# Product 'FILIGREE DIAMANTE CHAIN' not found in the model vocabulary.
# Product 'code mix up? 84930' not found in the model vocabulary.
# Product '?display?' not found in the model vocabulary.
# Product 'crushed ctn' not found in the model vocabulary.
# Product 'MINT DINER CLOCK' not found in the model vocabulary.
# Product 'ENAMEL DINNER PLATE PANTRY' not found in the model vocabulary.
# Product 'Crushed' not found in the model vocabulary.
# Product 'temp adjustment' not found in the model vocabulary.
# Product 'PAINTED HEART WREATH WITH BELL' not found in the model vocabulary.
# Product 'allocate stock for dotcom orders ta' not found in the model vocabulary.
# Product 'add stock to allocate online orders' not found in the model vocabulary.
# Product 'for online retail orders' not found in the model vocabulary.
# Product 'found box' not found in the model vocabulary.
# Product 'OOPS ! adjustment' not found in the model vocabulary.
# Product 'Found in w/hse' not found in the model vocabulary.
# Product 'website fixed' not found in the model vocabulary.
# Product 'FLOWER FAIRY 5 SUMMER DRAW LINERS' not found in the model vocabulary.
# Product 'Dagamed' not found in the model vocabulary.
# Product 'DOLLY GIRL MINI RUCKSACK' not found in the model vocabulary.
# Product 'historic computer difference?....se' not found in the model vocabulary.
# Product 'Lighthouse Trading zero invc incorr' not found in the model vocabulary.
# Product 'Incorrect stock entry.' not found in the model vocabulary.
# Product 'michel oops' not found in the model vocabulary.
# Product 'SET 10 CARDS 12 DAYS OF XMAS 17059' not found in the model vocabulary.
# Product 'I LOVE LONDON MINI RUCKSACK' not found in the model vocabulary.
# Product 'SET 36 COLOURING PENCILS DOILEY' not found in the model vocabulary.
# Product 'SET 12 COLOURING PENCILS DOILEY' not found in the model vocabulary.
# Product 'WOODLAND MINI RUCKSACK' not found in the model vocabulary.
# Product 'wrongly coded-23343' not found in the model vocabulary.
# Product 'WALL ART,ONLY ONE PERSON' not found in the model vocabulary.
# Product 'crushed boxes' not found in the model vocabulary.
# Product 'WET/MOULDY' not found in the model vocabulary.
# Product 'can't find' not found in the model vocabulary.
# Product 'WALL ART , THE MAGIC FOREST' not found in the model vocabulary.
# Product 'S/4 BLACK DISCO PARTITION PANEL' not found in the model vocabulary.
# Product 'ORANGE PENDANT TRIPLE SHELL NECKLAC' not found in the model vocabulary.
# Product 'mouldy' not found in the model vocabulary.
# Product 'Wet pallet-thrown away' not found in the model vocabulary.
# Product 'Had been put aside.' not found in the model vocabulary.
# Product 'Sale error' not found in the model vocabulary.
# Product 'ROCOCO WALL MIROR' not found in the model vocabulary.
# Product 'SET OF 3 MINI HANGING PORTRAITS' not found in the model vocabulary.
# Product 'Amazon Adjustment' not found in the model vocabulary.
# Product 'wrongly marked 23343' not found in the model vocabulary.
# Product '20713 wrongly marked' not found in the model vocabulary.
# Product 're-adjustment' not found in the model vocabulary.
# Product 'Breakages' not found in the model vocabulary.
# Product 'Marked as 23343' not found in the model vocabulary.
# Product 'wrongly coded 23343' not found in the model vocabulary.
# Product 'Found by jackie' not found in the model vocabulary.
# Product 'Damages' not found in the model vocabulary.
# Product 'CORDIAL JUG' not found in the model vocabulary.
# Product 'SET 10 CARDS TRIANGLE ICONS  17220' not found in the model vocabulary.
# Product 'SET 10 CARDS CHRISTMAS BAUBLE 16954' not found in the model vocabulary.
# Product 'wrongly marked' not found in the model vocabulary.
# Product 'dotcom sales' not found in the model vocabulary.
# Product 'LIGHT DECORATION BATTERY OPERATED' not found in the model vocabulary.
# Product 'RUBY GLASS CLUSTER NECKLACE' not found in the model vocabulary.
# Product 'ANT SILVER TURQUOISE BOUDICCA RING' not found in the model vocabulary.
# Product 'water damaged' not found in the model vocabulary.
# Product 'WRAP A PRETTY THANK YOU' not found in the model vocabulary.
# Product 'CLASSIC CROME BICYCLE BELL' not found in the model vocabulary.
# Product 'Wrongly mrked had 85123a in box' not found in the model vocabulary.
# Product 'wrongly marked carton 22804' not found in the model vocabulary.
# Product 'LARGE PARLOUR FRAME' not found in the model vocabulary.
# Product 'MEDIUM PARLOUR FRAME' not found in the model vocabulary.
# Product 'SMALL PARLOUR FRAME' not found in the model vocabulary.
# Product 'SET 10 CARDS 3 WISE MEN 17107' not found in the model vocabulary.
# Product 'FLOWER SHOP DESIGN MUG' not found in the model vocabulary.
# Product 'missing?' not found in the model vocabulary.
# Product 'SET OF 6 EASTER RAINBOW CHICKS' not found in the model vocabulary.
# Product 'amazon adjust' not found in the model vocabulary.
# Product '???lost' not found in the model vocabulary.
# Product 'dotcomstock' not found in the model vocabulary.
# Product 'SET 10 CARD CHRISTMAS STAMPS 16963' not found in the model vocabulary.
# Product 'John Lewis' not found in the model vocabulary.
# Product 'sold with wrong barcode' not found in the model vocabulary.
# Product 'CAT WITH SUNGLASSES BLANK CARD' not found in the model vocabulary.
# Product 'dotcom adjust' not found in the model vocabulary.
# Product 'rusty thrown away' not found in the model vocabulary.
# Product 'check?' not found in the model vocabulary.
# Product '?? missing' not found in the model vocabulary.
# Product '????missing' not found in the model vocabulary.
# Product 'CROCHET LILAC/RED BEAR KEYRING' not found in the model vocabulary.
# Product 'LARGE HEART FLOWERS HOOK' not found in the model vocabulary.
# Product 'SET 10 CARDS SNOWY ROBIN 17099' not found in the model vocabulary.
# Product 'lost in space' not found in the model vocabulary.
# Product 'SET 10 CARDS SWIRLY XMAS TREE 17104' not found in the model vocabulary.
# Product 'wet?' not found in the model vocabulary.
# Product 'lost??' not found in the model vocabulary.
# Product '???' not found in the model vocabulary.
# Product 'LETTER "U" BLING KEY RING' not found in the model vocabulary.
# Product 'wet' not found in the model vocabulary.
# Product 'wet boxes' not found in the model vocabulary.
# Product '????damages????' not found in the model vocabulary.
# Product 'lost' not found in the model vocabulary.
# Product 'PAPER CRAFT , LITTLE BIRDIE' not found in the model vocabulary.
# Analyzing complementary products...
# 2025-04-06 15:30:59,388 : INFO : Word2Vec lifecycle event {'fname_or_handle': 'C:\\Users\\moham\\Apriori_VS_Word2Vec\\Dataset\\comprehensive_product2vec_model.bin', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2025-04-06T15:30:59.388482', 'gensim': '4.3.3', 'python': '3.10.16 | packaged by Anaconda, Inc. | (main, Dec 11 2024, 16:19:12) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'saving'}
# 2025-04-06 15:30:59,389 : INFO : not storing attribute cum_table
# 2025-04-06 15:30:59,401 : INFO : saved C:\Users\moham\Apriori_VS_Word2Vec\Dataset\comprehensive_product2vec_model.bin
# Complementary Products Analysis:
#
# Total Unique Original Products:
# 3877
#
# Total Complementary Product Pairs:
# 38770
#
# Average Similarity Score:
# 0.7385364575348535
#
# Median Similarity Score:
# 0.7312331795692444
#
# Top 10 Strongest Complementary Relationships:
#                          Original Product               Complementary Product  \
# 34540          AMBER 3 BEAD DROP EARRINGS          BLACK 3 BEAD DROP EARRINGS
# 27120          BLACK 3 BEAD DROP EARRINGS          AMBER 3 BEAD DROP EARRINGS
# 26150  TURQ PENDANT TRIPLE SHELL NECKLACE        GREEN STONE/CRYSTAL EARRINGS
# 20460        GREEN STONE/CRYSTAL EARRINGS  TURQ PENDANT TRIPLE SHELL NECKLACE
# 27121          BLACK 3 BEAD DROP EARRINGS    BLACK DROP EARRINGS W LONG BEADS
# 28430    BLACK DROP EARRINGS W LONG BEADS          BLACK 3 BEAD DROP EARRINGS
# 26930       PINK ROSEBUD & PEARL NECKLACE       CLASSIC DIAMANTE EARRINGS JET
# 29440       CLASSIC DIAMANTE EARRINGS JET       PINK ROSEBUD & PEARL NECKLACE
# 23480          IVORY SHELL HEART EARRINGS        CRACKED GLAZE EARRINGS BROWN
# 26370        CRACKED GLAZE EARRINGS BROWN          IVORY SHELL HEART EARRINGS
#
#        Similarity Score
# 34540          0.996275
# 27120          0.996275
# 26150          0.995884
# 20460          0.995884
# 27121          0.995790
# 28430          0.995790
# 26930          0.995195
# 29440          0.995195
# 23480          0.994836
# 26370          0.994836
#
# Results saved to C:\Users\moham\Apriori_VS_Word2Vec\Dataset\comprehensive_complementary_products.xlsx
# Model saved to C:\Users\moham\Apriori_VS_Word2Vec\Dataset\comprehensive_product2vec_model.bin

# %% [markdown]
# ## **COMPARASION METRICS**
